# %% [markdown]
# 1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius

# %%
obj = Circle(2.5)
print("Area:", obj.area())
print("Perimeter:", obj.perimeter())
# Out:
# Area: 19.634954084936208
# Perimeter: 15.707963267948966

# %% [markdown]
# 2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
class Person:
    def __init__(self, name, country, date_of_birth):
        self.name = name
        self.country = country
        self.date_of_birth = date_of_birth

    def details(self):
        age = 2026 - int(self.date_of_birth)
        print(f"this is {self.name}, he is {age} years old, and was born in {self.country}")

# %%
obj=Person("ali","Morroco",2010)

# %%
obj.details()
# Out:
# this is ali, he is 16 years old, and was born in Morroco

# %% [markdown]
# 3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

# %%
calc = Calculator()
print(calc.add(4, 5))
print(calc.subtract(10, 3))
print(calc.multiply(6, 7))
# Out:
# 9
# 7
# 42

# %% [markdown]
# ## LISTS

# %% [markdown]
# 4. Create a list of  15 student names and print each name using a for loop.

# %%
list=["hamza","ahmed","ali","usman","khizer","husnain","muhammad","ammar","abu bakr","alyaan","younus","hussain","riaz","abdulahad","abdullah"]
for temp in list:
    print(temp)
# Out:
# hamza
# ahmed
# ali
# usman
# khizer
# husnain
# muhammad
# ammar
# abu bakr
# alyaan
# younus
# hussain
# riaz
# abdulahad
# abdullah

# %% [markdown]
# 5. Create a list of numbers from 1 to 10. Print only the even numbers.

# %%
for num in list:
    if num % 2 == 0:
        print(num)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# 6. Create a list of five numbers and find the largest and smallest number without using the max() & min() function.

# %%
list=[5,13,9,32,28]
smallest = largest = list[0]
for num in list:
	if num < smallest:
		smallest = num
	if num > largest:
		largest = num

print(f"smallest number:{smallest}")
print(f"largest number:{largest}")
# Out:
# smallest number:5
# largest number:32

# %% [markdown]
# 7. Count how many times "Apple" appears in the following list.
# fruits = ["Apple", "Banana", "Apple", "Orange", "Apple"]

# %%
fruits = ["Apple", "Banana", "Apple", "Orange", "Apple"]
count = fruits.count("Apple")
print(f"'Apple' appears {count} times in the list")
# Out:
# 'Apple' appears 3 times in the list

# %% [markdown]
# 8. Create a list of numbers and sort it in:
# - Ascending order
# - Descending order

# %%
list =[3,9,65,33,21,16]
list.sort()
print(list)
list.sort(reverse=True)
print(list)
# Out:
# [3, 9, 16, 21, 33, 65]
# [65, 33, 21, 16, 9, 3]

# %% [markdown]
# 9. Copy one list into another list and print both lists.

# %%
list= [1,2,3]
new_list=list.copy()
print(list)
print(new_list)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %% [markdown]
# 10. Create the following nested list:
#
# - students = [
# -     ["Ali", 20],
# -     ["Ahmed", 18],
# -     ["Sara", 19]
# - ]
# - Print:
# - All student names
# - All student ages

# %%
students = [
     ["Ali", 20],
     ["Ahmed", 18],
     ["Sara", 19]
]
names = [s[0] for s in students]
ages = [s[1] for s in students]
# Out:
# All student names:
# Ali
# Ahmed
# Sara
#
# All student ages:
# 20
# 18
# 19

# %% [markdown]
# 11. Create a list of 10 numbers. Print:
# - Total numbers
# - Sum
# - Average
# - Maximum value
# - Minimum value

# %%
import statistics
numbers =[2,4,3,23,15,41,9,18,26,39]

total_count = len(numbers)
total_sum = sum(numbers)
average = statistics.mean(numbers)
min_value = min(numbers)
max_value = max(numbers)

print(total_count)
print(total_sum)
print(average)
print(min_value)
print(max_value)
# Out:
# 10
# 180
# 18
# 2
# 41

# %% [markdown]
# 12. Perform the following operations on a list:
# - Append one item
# - Insert one item
# - Remove one item
# - Pop one item
# - Print the list after each operation.

# %%
list=["uzair","muhammad","younus","yousuf","ali","usman"]
list.append("hassan")
print(list)
list.insert(4,"hussain")
print(list)
list.remove("uzair")
print(list)
list.pop(0)
print(list)
# Out:
# ['uzair', 'muhammad', 'younus', 'yousuf', 'ali', 'usman', 'hassan']
# ['uzair', 'muhammad', 'younus', 'yousuf', 'hussain', 'ali', 'usman', 'hassan']
# ['muhammad', 'younus', 'yousuf', 'hussain', 'ali', 'usman', 'hassan']
# ['younus', 'yousuf', 'hussain', 'ali', 'usman', 'hassan']
